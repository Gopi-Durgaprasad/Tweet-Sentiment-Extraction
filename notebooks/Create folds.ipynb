# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
os.chdir("drive/My Drive/kaggle-tweet-sentiment-extraction/input")
# !pwd
# Out:
# /content/drive/My Drive/kaggle-tweet-sentiment-extraction/input

# %%
import pandas as pd
from sklearn.model_selection import KFold, StratifiedKFold

df = pd.read_csv("train.csv")

# %%
seed = 42

df = pd.read_csv("../input/train.csv")
print(df.head())
df.loc[:, "kfold"] = -1

df = df.sample(frac=1, random_state=seed).reset_index(drop=True)

X = df.textID.values
y = df.sentiment.values

kfold = StratifiedKFold(n_splits=5, random_state=seed, shuffle=True)

for fold, (trn_, val_) in enumerate(kfold.split(X, y)):
    df.loc[val_, "kfold"] = fold

print(df.kfold.value_counts())
print(df.sentiment.value_counts())
df.to_csv(f"../input/train_5folds_seed{seed}.csv", index=False)
# Out:
#        textID  ... sentiment
# 0  cb774db0d1  ...   neutral
# 1  549e992a42  ...  negative
# 2  088c60f138  ...  negative
# 3  9642c003ef  ...  negative
# 4  358bd9e861  ...  negative
#
# [5 rows x 4 columns]
# 0    5497
# 4    5496
# 3    5496
# 2    5496
# 1    5496
# Name: kfold, dtype: int64
# neutral     11118
# positive     8582
# negative     7781
# Name: sentiment, dtype: int64

# %%
seed = 123

df = pd.read_csv("../input/train.csv")
print(df.head())
df.loc[:, "kfold"] = -1

df = df.sample(frac=1, random_state=seed).reset_index(drop=True)

X = df.textID.values
y = df.sentiment.values

kfold = StratifiedKFold(n_splits=5, random_state=seed, shuffle=True)

for fold, (trn_, val_) in enumerate(kfold.split(X, y)):
    df.loc[val_, "kfold"] = fold

print(df.kfold.value_counts())
df.to_csv(f"../input/train_5folds_seed{seed}.csv", index=False)
# Out:
#        textID  ... sentiment
# 0  cb774db0d1  ...   neutral
# 1  549e992a42  ...  negative
# 2  088c60f138  ...  negative
# 3  9642c003ef  ...  negative
# 4  358bd9e861  ...  negative
#
# [5 rows x 4 columns]
# 0    5497
# 4    5496
# 3    5496
# 2    5496
# 1    5496
# Name: kfold, dtype: int64

# %%
seed = 24

df = pd.read_csv("../input/train.csv")
print(df.head())
df.loc[:, "kfold"] = -1

df = df.sample(frac=1, random_state=seed).reset_index(drop=True)

X = df.textID.values
y = df.sentiment.values

kfold = StratifiedKFold(n_splits=5, random_state=seed, shuffle=True)

for fold, (trn_, val_) in enumerate(kfold.split(X, y)):
    df.loc[val_, "kfold"] = fold

print(df.kfold.value_counts())
df.to_csv(f"../input/train_5folds_seed{seed}.csv", index=False)
# Out:
#        textID  ... sentiment
# 0  cb774db0d1  ...   neutral
# 1  549e992a42  ...  negative
# 2  088c60f138  ...  negative
# 3  9642c003ef  ...  negative
# 4  358bd9e861  ...  negative
#
# [5 rows x 4 columns]
# 0    5497
# 4    5496
# 3    5496
# 2    5496
# 1    5496
# Name: kfold, dtype: int64

# %%
seed = 101

df = pd.read_csv("../input/train.csv")
print(df.head())
df.loc[:, "kfold"] = -1

df = df.sample(frac=1, random_state=seed).reset_index(drop=True)

X = df.textID.values
y = df.sentiment.values

kfold = StratifiedKFold(n_splits=5, random_state=seed, shuffle=True)

for fold, (trn_, val_) in enumerate(kfold.split(X, y)):
    df.loc[val_, "kfold"] = fold

print(df.kfold.value_counts())
df.to_csv(f"../input/train_5folds_seed{seed}.csv", index=False)
# Out:
#        textID  ... sentiment
# 0  cb774db0d1  ...   neutral
# 1  549e992a42  ...  negative
# 2  088c60f138  ...  negative
# 3  9642c003ef  ...  negative
# 4  358bd9e861  ...  negative
#
# [5 rows x 4 columns]
# 0    5497
# 4    5496
# 3    5496
# 2    5496
# 1    5496
# Name: kfold, dtype: int64

# %%
seed = 1001

df = pd.read_csv("../input/train.csv")
print(df.head())
df.loc[:, "kfold"] = -1

df = df.sample(frac=1, random_state=seed).reset_index(drop=True)

X = df.textID.values
y = df.sentiment.values

kfold = StratifiedKFold(n_splits=5, random_state=seed, shuffle=True)

for fold, (trn_, val_) in enumerate(kfold.split(X, y)):
    df.loc[val_, "kfold"] = fold

print(df.kfold.value_counts())
df.to_csv(f"../input/train_5folds_seed{seed}.csv", index=False)
# Out:
#        textID  ... sentiment
# 0  cb774db0d1  ...   neutral
# 1  549e992a42  ...  negative
# 2  088c60f138  ...  negative
# 3  9642c003ef  ...  negative
# 4  358bd9e861  ...  negative
#
# [5 rows x 4 columns]
# 0    5497
# 4    5496
# 3    5496
# 2    5496
# 1    5496
# Name: kfold, dtype: int64

# %%
seed = 1001

df = pd.read_csv("../input/train.csv")
print(df.head())
df.loc[:, "kfold"] = -1

df = df.sample(frac=1, random_state=seed).reset_index(drop=True)

X = df.textID.values
y = df.sentiment.values

kfold = StratifiedKFold(n_splits=2, random_state=seed, shuffle=True)

for fold, (trn_, val_) in enumerate(kfold.split(X, y)):
    df.loc[val_, "kfold"] = fold

print(df.kfold.value_counts())
df.to_csv(f"../input/train_2folds_seed{seed}.csv", index=False)
# Out:
#        textID  ... sentiment
# 0  cb774db0d1  ...   neutral
# 1  549e992a42  ...  negative
# 2  088c60f138  ...  negative
# 3  9642c003ef  ...  negative
# 4  358bd9e861  ...  negative
#
# [5 rows x 4 columns]
# 0    13741
# 1    13740
# Name: kfold, dtype: int64

# %%
seed = 1001

df = pd.read_csv("../input/train.csv")
print(df.head())
df.loc[:, "kfold"] = -1

df = df.sample(frac=1, random_state=seed).reset_index(drop=True)

X = df.textID.values
y = df.sentiment.values

kfold = StratifiedKFold(n_splits=3, random_state=seed, shuffle=True)

for fold, (trn_, val_) in enumerate(kfold.split(X, y)):
    df.loc[val_, "kfold"] = fold

print(df.kfold.value_counts())
df.to_csv(f"../input/train_3folds_seed{seed}.csv", index=False)
# Out:
#        textID  ... sentiment
# 0  cb774db0d1  ...   neutral
# 1  549e992a42  ...  negative
# 2  088c60f138  ...  negative
# 3  9642c003ef  ...  negative
# 4  358bd9e861  ...  negative
#
# [5 rows x 4 columns]
# 0    9161
# 2    9160
# 1    9160
# Name: kfold, dtype: int64

# %%
seed = 1001

df = pd.read_csv("../input/train.csv")
print(df.head())
df.loc[:, "kfold"] = -1

df = df.sample(frac=1, random_state=seed).reset_index(drop=True)

X = df.textID.values
y = df.sentiment.values

kfold = StratifiedKFold(n_splits=4, random_state=seed, shuffle=True)

for fold, (trn_, val_) in enumerate(kfold.split(X, y)):
    df.loc[val_, "kfold"] = fold

print(df.kfold.value_counts())
df.to_csv(f"../input/train_4folds_seed{seed}.csv", index=False)
# Out:
#        textID  ... sentiment
# 0  cb774db0d1  ...   neutral
# 1  549e992a42  ...  negative
# 2  088c60f138  ...  negative
# 3  9642c003ef  ...  negative
# 4  358bd9e861  ...  negative
#
# [5 rows x 4 columns]
# 0    6871
# 3    6870
# 2    6870
# 1    6870
# Name: kfold, dtype: int64
