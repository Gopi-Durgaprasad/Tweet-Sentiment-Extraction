# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pip install kaggle

# %%
! mkdir /root/.kaggle
! cp '/content/drive/My Drive/kaggle.json' /root/.kaggle
! chmod 400 /root/.kaggle/kaggle.json

# %%
# !mkdir "weights"

# %%
# !cp "drive/My Drive/kaggle-tweet-sentiment-extraction/weights/xlm-roberta-base/base_seed42/fold_0" "weights"
# !cp "drive/My Drive/kaggle-tweet-sentiment-extraction/weights/xlm-roberta-base/base_seed42/fold_1"  "weights"
# !cp "drive/My Drive/kaggle-tweet-sentiment-extraction/weights/xlm-roberta-base/base_seed42/fold_2"  "weights"
# !cp "drive/My Drive/kaggle-tweet-sentiment-extraction/weights/xlm-roberta-base/base_seed42/fold_3"  "weights"
# !cp "drive/My Drive/kaggle-tweet-sentiment-extraction/weights/xlm-roberta-base/base_seed42/fold_4"  "weights"

# %%
dataset_path = "weights/"

# %%
# !ls -ls "$dataset_path"
# Out:
# total 14632964
#       4 -rw-r--r-- 1 root root        137 Jun  4 17:14 dataset-metadata.json
# 2926592 -rw------- 1 root root 2996822514 Jun  4 17:07 fold_0
# 2926592 -rw------- 1 root root 2996822416 Jun  4 17:08 fold_1
# 2926592 -rw------- 1 root root 2996822446 Jun  4 17:10 fold_2
# 2926592 -rw------- 1 root root 2996822326 Jun  4 17:12 fold_3
# 2926592 -rw------- 1 root root 2996822480 Jun  4 17:14 fold_4

# %%
! kaggle datasets init -p "$dataset_path"
# Out:
# Data package template written to: weights/dataset-metadata.json

# %%
cat "$dataset_path"/dataset-metadata.json
# Out:
# {
#   "licenses": [
#     {
#       "name": "CC0-1.0"
#     }
#   ],
#   "id": "gopidurgaprasad/INSERT_SLUG_HERE",
#   "title": "INSERT_TITLE_HERE"
# }

# %%
import json
metadata = {}
metadata['licenses'] = [{'name': 'CC0-1.0'}]
metadata['id'] = "gopidurgaprasad/xlm-roberta-42-weights"
metadata['title'] = "xlm-roberta-42-weights"
with open(dataset_path+"/dataset-metadata.json","w") as mfile:
  json.dump(metadata, mfile)

# %%
cat "$dataset_path"/dataset-metadata.json
# Out:
# {"licenses": [{"name": "CC0-1.0"}], "id": "gopidurgaprasad/xlm-roberta-42-weights", "title": "xlm-roberta-42-weights"}

# %%
! kaggle datasets create -p "$dataset_path"
# ! kaggle datasets version -p $dataset_path -m "New dataset"
# Out:
# Starting upload for file fold_1
# ...
# 100% 2.79G/2.79G [00:55<00:00, 54.1MB/s]
# Upload successful: fold_1 (3GB)
# Starting upload for file fold_2
# 100% 2.79G/2.79G [00:55<00:00, 54.1MB/s]
# Upload successful: fold_2 (3GB)
# Starting upload for file fold_0
# 100% 2.79G/2.79G [00:57<00:00, 52.3MB/s]
# Upload successful: fold_0 (3GB)
# Starting upload for file fold_4
# 100% 2.79G/2.79G [00:55<00:00, 54.0MB/s]
# Upload successful: fold_4 (3GB)
# Starting upload for file fold_3
# 100% 2.79G/2.79G [00:55<00:00, 54.1MB/s]
# Upload successful: fold_3 (3GB)
# Your private Dataset is being created. Please check progress at https://www.kaggle.com/gopidurgaprasad/xlm-roberta-42-weights
